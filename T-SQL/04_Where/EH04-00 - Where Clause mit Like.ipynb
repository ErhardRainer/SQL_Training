-- %% [markdown]
-- # Filterung von Daten (mit Ähnlichkeit)
--
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- bisherige Besipiele:

-- %%
Select * from [Person].[Address]
  Where AddressLine1 = '8401 Carson Street'
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:01.122
-- <table><tr><th>AddressID</th><th>AddressLine1</th><th>AddressLine2</th><th>City</th><th>StateProvinceID</th><th>PostalCode</th><th>SpatialLocation</th><th>rowguid</th><th>ModifiedDate</th></tr><tr><td>26312</td><td>8401 Carson Street</td><td>NULL</td><td>W. Linn</td><td>58</td><td>97068</td><td>0xE6100000010C0B68C04CD7AA4640D6B90F6086AC5EC0</td><td>ff1e4172-683b-4bac-a064-1cfc8490813c</td><td>2014-04-07 00:00:00.000</td></tr><tr><td>11702</td><td>8401 Carson Street</td><td>#e</td><td>Les Ulis</td><td>177</td><td>91940</td><td>0xE6100000010CAD2D7743054D4840059F6DEDC84F0140</td><td>8a32df46-6503-4276-ae71-437363ab35cd</td><td>2013-12-21 10:09:29.423</td></tr></table>

-- %%
Select * from [Person].[Address]
  Where left(AddressLine1,4) = '8401'
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.037
-- <table><tr><th>AddressID</th><th>AddressLine1</th><th>AddressLine2</th><th>City</th><th>StateProvinceID</th><th>PostalCode</th><th>SpatialLocation</th><th>rowguid</th><th>ModifiedDate</th></tr><tr><td>26312</td><td>8401 Carson Street</td><td>NULL</td><td>W. Linn</td><td>58</td><td>97068</td><td>0xE6100000010C0B68C04CD7AA4640D6B90F6086AC5EC0</td><td>ff1e4172-683b-4bac-a064-1cfc8490813c</td><td>2014-04-07 00:00:00.000</td></tr><tr><td>11702</td><td>8401 Carson Street</td><td>#e</td><td>Les Ulis</td><td>177</td><td>91940</td><td>0xE6100000010CAD2D7743054D4840059F6DEDC84F0140</td><td>8a32df46-6503-4276-ae71-437363ab35cd</td><td>2013-12-21 10:09:29.423</td></tr></table>

-- %% [markdown]
-- ## Ähnlichkeitsvergleich mittels Like
--
-- ![](data:image/png;base64,...)
--
-- Details: https://docs.microsoft.com/en-us/sql/t-sql/language-elements/like-transact-sql?view=sql-server-ver15

-- %% [markdown]
-- Gib mir alle AddressLines2 aus, die eine Raute (#) beinhalten:

-- %%
Select * from .[Person].[Address]
  Where AddressLine2 like '%#%'
-- Out:
-- (204 rows affected)
-- Total execution time: 00:00:00.066
-- ...

-- %% [markdown]
-- Gib mir alle AddressLinkes2 aus, die mit einer Raute (#) anfangen:

-- %%
Select * from [Person].[Address]
  Where AddressLine2 like '#%'
-- Out:
-- (199 rows affected)
-- Total execution time: 00:00:00.038
-- ...

-- %% [markdown]
-- Gib mir alle AddressLines2 aus, die mit einer Zahl zwischen 0 und 9 starten

-- %%
Select * from [Person].[Address]
  Where AddressLine2 like '[0-9]%' -- Zeichenfolge, die mit 0-9 startet

-- %% [markdown]
-- Gib mir alle AddessLines2 aus, die mit einem (Groß)buchstaben starten:

-- %%
Select * from [Person].[Address]
  Where AddressLine2 like '[A-Z]%' -- Zeichenfolge, die mit A-Z startet

-- %% [markdown]
-- Gib mir alle AddessLines2 aus, die mit \_nit starten

-- %%
Select * from [Person].[Address]
where AddressLine2 like '_nit%'

-- %% [markdown]
-- **<u>Suchen nach %-Zeichen und anderen geschützten Zeichen</u>**

-- %%
  IF OBJECT_ID('tempdb..#PercentageSearch') IS NOT NULL DROP TABLE #PercentageSearch
  Select 'das ist ein % Test' as [T] into #PercentageSearch
  INSERT INTO #PercentageSearch (T)
  Select 'das ist ein Test 2'
  INSERT INTO #PercentageSearch (T)
  Select 'das ist ein Test _'

Select * from #PercentageSearch
Where [T] like '%[%]%'
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.195
-- <table><tr><th>T</th></tr><tr><td>das ist ein % Test</td></tr></table>

-- %%
  IF OBJECT_ID('tempdb..#PercentageSearch') IS NOT NULL DROP TABLE #PercentageSearch
  Select Cast('das ist ein % Test' as varchar(100)) as [T] into #PercentageSearch
  INSERT INTO #PercentageSearch (T)
  Select 'das ist ein Test 2'
  INSERT INTO #PercentageSearch (T)
  Select 'das ist ein Test _'
  INSERT INTO #PercentageSearch (T)
  Select 'das ist ein Test _ XX'  

Select * from #PercentageSearch
Where [T] like '%[_]%'
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>T</th></tr><tr><td>das ist ein Test _</td></tr><tr><td>das ist ein Test _ XX</td></tr></table>
